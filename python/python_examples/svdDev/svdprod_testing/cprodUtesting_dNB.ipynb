# %%
import pyJvsip as pv

# %% [markdown]
# #### Begin Simple Test of produ ####
# Note there are many posibilities not covered here. Passing these tests just means the code is not totally brain-dead.
# Documentation is small here. Read the code to figure out what is going on.

# %% [markdown]
# >Cases SVD FULL
# >>+ $M < N$; NTRANS; RSIDE
# >>+ $M < N$; NTRANS; LSIDE
# >>+ $M < N$; HERM; RSIDE
# >>+ $M < N$; HERM; LSIDE
# >>+ $M \geq N$; NTRANS; RSIDE
# >>+ $M \geq N$; NTRANS; LSIDE
# >>+ $M \geq N$; HERM; RSIDE
# >>+ $M \geq N$; HERM; LSIDE
#
# >Cases SVD PART
# >>+ $M < N$; NTRANS; RSIDE
# >>+ $M < N$; NTRANS; LSIDE
# >>+ $M < N$; HERM; RSIDE
# >>+ $M < N$; HERM; LSIDE
# >>+ $M \geq N$; NTRANS; RSIDE
# >>+ $M \geq N$; NTRANS; LSIDE
# >>+ $M \geq N$; HERM; RSIDE
# >>+ $M \geq N$; HERM; LSIDE

# %%
print('case RSIDE, m < n; FULL decomposition')
m=4;n=6
A=pv.create('cmview_d',m,n).fill(0.0)
A.realview.block.vector.randn(5)
A.imagview.block.vector.randn(7)
f='%.3f'
print('Test matrix')
A.mprint(f)
u,s,v=A.copy.svd
B=u.empty.fill(0.0)
B.diagview(0).fill(1)
B.mprint(f)
d=pv.SV('csv_d',m,n,'FULL','FULL')
S=s.empty.fill(0.0)
_=d.svd(A.copy,S)
print('should be the same')
S.mprint(f)
s.mprint(f)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_NTRANS,pv.VSIP_MAT_RSIDE,B.view)
print('should be the same; norm of difference should be small')
B.mprint(f)
u.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-u).normFro)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_RSIDE,B.view)
print('should be identity matrix')
B.mprint(f)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_RSIDE,B.view)
print('\nshould be the same; norm of difference should be small')
B.mprint(f)
u.herm.mprint(f)
print('Frobenius Norm %.4e'%(B-u.herm).normFro)
# Out:
# case RSIDE, m < n; FULL decomposition
# Test matrix
# [ 0.508-0.050i  0.535+0.590i  0.699+0.728i -0.960-0.368i  0.231-0.209i  0.040-0.827i;
#  -0.477-0.679i  0.208+0.012i  0.506-0.742i -0.383+0.375i  0.157-1.112i  0.781+2.007i;
#  -0.968+0.439i -0.320+1.269i  0.793+0.678i  0.792-0.770i -0.258+0.499i  0.127+0.760i;
#   1.355+0.521i  0.255+1.624i -0.195-0.320i  0.341-0.422i -0.496-1.176i  0.172+0.459i]
#
# [ 1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i]
#
# should be the same
# [ 3.144  2.926  2.151  1.258]
#
# [ 3.144  2.926  2.151  1.258]
#
# should be the same; norm of difference should be small
# [-0.291-0.000i  0.451-0.000i  0.123-0.000i -0.835-0.000i;
#  -0.159-0.259i -0.589-0.639i  0.177+0.048i -0.237-0.248i;
#   0.135-0.557i  0.003+0.196i  0.433+0.548i  0.019+0.381i;
# ...

# %%
print('case LSIDE, m < n; FULL decomposition')
m=4;n=6
A=pv.create('cmview_d',m,n).fill(0.0)
A.realview.block.vector.randn(5)
A.imagview.block.vector.randn(7)
f='%.3f'
A.mprint(f)
u,s,v=A.copy.svd
B=u.empty.fill(0.0)
B.diagview(0).fill(1)
B.mprint(f)
d=pv.SV('csv_d',m,n,'FULL','FULL')
S=s.empty.fill(0.0)
_=d.svd(A.copy,S)
print('should be the same')
S.mprint(f)
s.mprint(f)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_NTRANS,pv.VSIP_MAT_LSIDE,B.view)
print('should be the same; norm of difference should be small')
B.mprint(f)
u.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-u).normFro)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_LSIDE,B.view)
print('should be identity matrix')
B.mprint(f)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_LSIDE,B.view)
print('\nshould be the same; norm of difference should be small')
B.mprint(f)
u.herm.mprint(f)
print('Frobenius Norm %.4e'%(B-u.herm).normFro)
# Out:
# case LSIDE, m < n; FULL decomposition
# [ 0.508-0.050i  0.535+0.590i  0.699+0.728i -0.960-0.368i  0.231-0.209i  0.040-0.827i;
#  -0.477-0.679i  0.208+0.012i  0.506-0.742i -0.383+0.375i  0.157-1.112i  0.781+2.007i;
#  -0.968+0.439i -0.320+1.269i  0.793+0.678i  0.792-0.770i -0.258+0.499i  0.127+0.760i;
#   1.355+0.521i  0.255+1.624i -0.195-0.320i  0.341-0.422i -0.496-1.176i  0.172+0.459i]
#
# [ 1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i]
#
# should be the same
# [ 3.144  2.926  2.151  1.258]
#
# [ 3.144  2.926  2.151  1.258]
#
# should be the same; norm of difference should be small
# [-0.291-0.000i  0.451-0.000i  0.123-0.000i -0.835-0.000i;
#  -0.159-0.259i -0.589-0.639i  0.177+0.048i -0.237-0.248i;
#   0.135-0.557i  0.003+0.196i  0.433+0.548i  0.019+0.381i;
# ...

# %%
print('case RSIDE, m > n; FULL decomposition')
m=6;n=4
A=pv.create('cmview_d',m,n).fill(0.0)
A.realview.block.vector.randn(5)
A.imagview.block.vector.randn(7)
f='%.3f'
A.mprint(f)
u,s,v=A.copy.svd
B=u.empty.fill(0.0)
B.diagview(0).fill(1)
B.mprint(f)
d=pv.SV('csv_d',m,n,'FULL','FULL')
S=s.empty.fill(0.0)
_=d.svd(A.copy,S)
print('should be the same')
S.mprint(f)
s.mprint(f)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_NTRANS,pv.VSIP_MAT_RSIDE,B.view)
print('should be the same; norm of difference should be small')
B.mprint(f)
u.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-u).normFro)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_RSIDE,B.view)
print('should be identity matrix')
B.mprint(f)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_RSIDE,B.view)
print('\nshould be the same; norm of difference should be small')
B.mprint(f)
u.herm.mprint(f)
print('Frobenius Norm %.4e'%(B-u.herm).normFro)
# Out:
# case RSIDE, m > n; FULL decomposition
# [ 0.508-0.050i  0.535+0.590i  0.699+0.728i -0.960-0.368i;
#   0.231-0.209i  0.040-0.827i -0.477-0.679i  0.208+0.012i;
#   0.506-0.742i -0.383+0.375i  0.157-1.112i  0.781+2.007i;
#  -0.968+0.439i -0.320+1.269i  0.793+0.678i  0.792-0.770i;
#  -0.258+0.499i  0.127+0.760i  1.355+0.521i  0.255+1.624i;
#  -0.195-0.320i  0.341-0.422i -0.496-1.176i  0.172+0.459i]
#
# [ 1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i]
#
# should be the same
# [ 3.700  2.981  1.124  0.899]
#
# ...

# %%
print('case LSIDE, m > n; FULL decomposition')
m=6;n=4
A=pv.create('cmview_d',m,n).fill(0.0)
A.realview.block.vector.randn(5)
A.imagview.block.vector.randn(7)
f='%.3f'
A.mprint(f)
u,s,v=A.copy.svd
B=u.empty.fill(0.0)
B.diagview(0).fill(1)
B.mprint(f)
d=pv.SV('csv_d',m,n,'FULL','FULL')
S=s.empty.fill(0.0)
_=d.svd(A.copy,S)
print('should be the same')
S.mprint(f)
s.mprint(f)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_NTRANS,pv.VSIP_MAT_LSIDE,B.view)
print('should be the same; norm of difference should be small')
B.mprint(f)
u.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-u).normFro)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_LSIDE,B.view)
print('should be identity matrix')
B.mprint(f)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_LSIDE,B.view)
print('\nshould be the same; norm of difference should be small')
B.mprint(f)
u.herm.mprint(f)
print('Frobenius Norm %.4e'%(B-u.herm).normFro)
# Out:
# case LSIDE, m > n; FULL decomposition
# [ 0.508-0.050i  0.535+0.590i  0.699+0.728i -0.960-0.368i;
#   0.231-0.209i  0.040-0.827i -0.477-0.679i  0.208+0.012i;
#   0.506-0.742i -0.383+0.375i  0.157-1.112i  0.781+2.007i;
#  -0.968+0.439i -0.320+1.269i  0.793+0.678i  0.792-0.770i;
#  -0.258+0.499i  0.127+0.760i  1.355+0.521i  0.255+1.624i;
#  -0.195-0.320i  0.341-0.422i -0.496-1.176i  0.172+0.459i]
#
# [ 1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i]
#
# should be the same
# [ 3.700  2.981  1.124  0.899]
#
# ...

# %%
print('case RSIDE, m < n; PART decomposition')
m=4;n=6
A=pv.create('cmview_d',m,n).fill(0.0)
A.realview.block.vector.randn(5)
A.imagview.block.vector.randn(7)
f='%.3f'
A.mprint(f)
u,s,v=A.copy.svdP
B=u.empty.fill(0.0)
B.diagview(0).fill(1)
B.mprint(f)
d=pv.SV('csv_d',m,n,'PART','PART')
S=s.empty.fill(0.0)
_=d.svd(A.copy,S)
print('should be the same')
S.mprint(f)
s.mprint(f)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_NTRANS,pv.VSIP_MAT_RSIDE,B.view)
print('should be the same; norm of difference should be small')
B.mprint(f)
u.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-u).normFro)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_RSIDE,B.view)
print('should be identity matrix')
B.mprint(f)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_RSIDE,B.view)
print('\nshould be the same; norm of difference should be small')
B.mprint(f)
u.herm.mprint(f)
print('Frobenius Norm %.4e'%(B-u.herm).normFro)
# Out:
# case RSIDE, m < n; PART decomposition
# [ 0.508-0.050i  0.535+0.590i  0.699+0.728i -0.960-0.368i  0.231-0.209i  0.040-0.827i;
#  -0.477-0.679i  0.208+0.012i  0.506-0.742i -0.383+0.375i  0.157-1.112i  0.781+2.007i;
#  -0.968+0.439i -0.320+1.269i  0.793+0.678i  0.792-0.770i -0.258+0.499i  0.127+0.760i;
#   1.355+0.521i  0.255+1.624i -0.195-0.320i  0.341-0.422i -0.496-1.176i  0.172+0.459i]
#
# [ 1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i]
#
# should be the same
# [ 3.144  2.926  2.151  1.258]
#
# [ 3.144  2.926  2.151  1.258]
#
# should be the same; norm of difference should be small
# [-0.291-0.000i  0.451-0.000i  0.123-0.000i -0.835-0.000i;
#  -0.159-0.259i -0.589-0.639i  0.177+0.048i -0.237-0.248i;
#   0.135-0.557i  0.003+0.196i  0.433+0.548i  0.019+0.381i;
# ...

# %%
print('case LSIDE, m < n; PART decomposition')
m=4;n=6
A=pv.create('cmview_d',m,n).fill(0.0)
A.realview.block.vector.randn(5)
A.imagview.block.vector.randn(7)
f='%.3f'
A.mprint(f)
u,s,v=A.copy.svdP
B=u.empty.fill(0.0)
B.diagview(0).fill(1)
B.mprint(f)
d=pv.SV('csv_d',m,n,'PART','PART')
S=s.empty.fill(0.0)
_=d.svd(A.copy,S)
print('should be the same')
S.mprint(f)
s.mprint(f)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_NTRANS,pv.VSIP_MAT_LSIDE,B.view)
print('should be the same; norm of difference should be small')
B.mprint(f)
u.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-u).normFro)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_LSIDE,B.view)
print('should be identity matrix')
B.mprint(f)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_LSIDE,B.view)
print('\nshould be the same; norm of difference should be small')
B.mprint(f)
u.herm.mprint(f)
print('Frobenius Norm %.4e'%(B-u.herm).normFro)
# Out:
# case LSIDE, m < n; PART decomposition
# [ 0.508-0.050i  0.535+0.590i  0.699+0.728i -0.960-0.368i  0.231-0.209i  0.040-0.827i;
#  -0.477-0.679i  0.208+0.012i  0.506-0.742i -0.383+0.375i  0.157-1.112i  0.781+2.007i;
#  -0.968+0.439i -0.320+1.269i  0.793+0.678i  0.792-0.770i -0.258+0.499i  0.127+0.760i;
#   1.355+0.521i  0.255+1.624i -0.195-0.320i  0.341-0.422i -0.496-1.176i  0.172+0.459i]
#
# [ 1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i]
#
# should be the same
# [ 3.144  2.926  2.151  1.258]
#
# [ 3.144  2.926  2.151  1.258]
#
# should be the same; norm of difference should be small
# [-0.291-0.000i  0.451-0.000i  0.123-0.000i -0.835-0.000i;
#  -0.159-0.259i -0.589-0.639i  0.177+0.048i -0.237-0.248i;
#   0.135-0.557i  0.003+0.196i  0.433+0.548i  0.019+0.381i;
# ...

# %% [markdown]
# For cases below matrix U will no longer be square. This means the output matrix is no longer the same size as the input matrix which complicates the problem of designing a data space with a suitable data footprint suitable for both input and output.

# %%
print('case RSIDE, m > n; PART decomposition')
m=6;n=4
A=pv.create('cmview_d',m,n).fill(0.0)
A.realview.block.vector.randn(5)
A.imagview.block.vector.randn(7)
f='%.3f'
A.mprint(f)
u,s,v=A.copy.svdP
B0=pv.create(u.type,u.collength,u.collength).fill(0.0)
B=B0[:,:u.rowlength]
B0.diagview(0).fill(1)
B0.mprint(f)
d=pv.SV('csv_d',m,n,'PART','PART')
S=s.empty.fill(0.0)
_=d.svd(A.copy,S)
print('should be the same')
S.mprint(f)
s.mprint(f)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_NTRANS,pv.VSIP_MAT_RSIDE,B0.view)
print('should be the same; norm of difference should be small')
B.mprint(f)
u.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-u).normFro)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_RSIDE,B.view)
print('shouldbe the same; norm of differences should be small')
print('result')
B0.mprint(f)
print('u.prod(u.herm) direct');u.prod(u.herm).mprint(f)
print('Frobenius Norm %.4e\n\n'%(B0-u.prod(u.herm)).normFro)
# Out:
# case RSIDE, m > n; PART decomposition
# [ 0.508-0.050i  0.535+0.590i  0.699+0.728i -0.960-0.368i;
#   0.231-0.209i  0.040-0.827i -0.477-0.679i  0.208+0.012i;
#   0.506-0.742i -0.383+0.375i  0.157-1.112i  0.781+2.007i;
#  -0.968+0.439i -0.320+1.269i  0.793+0.678i  0.792-0.770i;
#  -0.258+0.499i  0.127+0.760i  1.355+0.521i  0.255+1.624i;
#  -0.195-0.320i  0.341-0.422i -0.496-1.176i  0.172+0.459i]
#
# [ 1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i]
#
# should be the same
# [ 3.700  2.981  1.124  0.899]
#
# ...

# %%
print('case LSIDE, m > n; PART decomposition')
m=6;n=4
A=pv.create('cmview_d',m,n).fill(0.0)
A.realview.block.vector.randn(5)
A.imagview.block.vector.randn(7)
f='%.3f'
print('input matrix and initial output matrix')
A.mprint(f)
u,s,v=A.copy.svdP
B0=pv.create(u.type,u.collength,u.rowlength).fill(0.0)
B=B0[:u.rowlength,:]
B.diagview(0).fill(1)
B0.mprint(f)
d=pv.SV('csv_d',m,n,'PART','PART')
S=s.empty.fill(0.0)
_=d.svd(A.copy,S)
print('should be the same')
S.mprint(f)
s.mprint(f)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_NTRANS,pv.VSIP_MAT_LSIDE,B.view)
print('should be the same; norm of difference should be small')
B0.mprint(f)
u.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-u).normFro)
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_LSIDE,B0.view)
print('should be identity matrix')
B.mprint(f)
B1=pv.create(u.type,u.collength,u.collength).fill(0.0)
B1.diagview(0).fill(1.0)
B=B1[:u.rowlength,:]
pv.vsip_csvdprodu_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_LSIDE,B1.view)
print('should be the same; norm of difference should be small')
B.mprint(f)
u.herm.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-u.herm).normFro)
# Out:
# case LSIDE, m > n; PART decomposition
# input matrix and initial output matrix
# [ 0.508-0.050i  0.535+0.590i  0.699+0.728i -0.960-0.368i;
#   0.231-0.209i  0.040-0.827i -0.477-0.679i  0.208+0.012i;
#   0.506-0.742i -0.383+0.375i  0.157-1.112i  0.781+2.007i;
#  -0.968+0.439i -0.320+1.269i  0.793+0.678i  0.792-0.770i;
#  -0.258+0.499i  0.127+0.760i  1.355+0.521i  0.255+1.624i;
#  -0.195-0.320i  0.341-0.422i -0.496-1.176i  0.172+0.459i]
#
# [ 1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i]
#
# should be the same
# [ 3.700  2.981  1.124  0.899]
#
# [ 3.700  2.981  1.124  0.899]
#
# should be the same; norm of difference should be small
# ...
