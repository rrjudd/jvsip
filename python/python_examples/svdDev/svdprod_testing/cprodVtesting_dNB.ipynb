# %%
import pyJvsip as pv

# %% [markdown]
# ####NEEDS WORK UNDER DEVELOPEMENT

# %% [markdown]
# case LSIDE, m < n; FULL decomposition
# case RSIDE, m < n; FULL decomposition
# case LSIDE, m > n; FULL decomposition
# case RSIDE, m > n; FULL decomposition
# case LSIDE, m < n; PART decomposition
# case RSIDE, m < n; PART decomposition
# case LSIDE, m > n; PART decomposition
# case RSIDE, m > n; PART decomposition

# %%
print('case LSIDE, m < n; FULL decomposition')
m=4;n=6
A=pv.create('cmview_d',m,n).fill(0.0)
A.realview.block.vector.randn(5)
A.imagview.block.vector.randn(7)
f='%.3f'
print('Test matrix')
A.mprint(f)
u,s,v=A.copy.svd
B=v.empty.fill(0.0)
B.diagview(0).fill(1)
B.mprint(f)
d=pv.SV('csv_d',m,n,'FULL','FULL')
S=s.empty.fill(0.0)
_=d.svd(A.copy,S)
print('should be the same')
S.mprint(f)
s.mprint(f)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_NTRANS,pv.VSIP_MAT_LSIDE,B.view)
print('should be the same; norm of difference should be small')
B.mprint(f)
v.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-v).normFro)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_LSIDE,B.view)
print('should be identity matrix')
B.mprint(f)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_LSIDE,B.view)
print('\nshould be the same; norm of difference should be small')
B.mprint(f)
v.herm.mprint(f)
print('Frobenius Norm %.4e'%(B-v.herm).normFro)
# Out:
# case LSIDE, m < n; FULL decomposition
# Test matrix
# [ 0.508-0.050i  0.535+0.590i  0.699+0.728i -0.960-0.368i  0.231-0.209i  0.040-0.827i;
#  -0.477-0.679i  0.208+0.012i  0.506-0.742i -0.383+0.375i  0.157-1.112i  0.781+2.007i;
#  -0.968+0.439i -0.320+1.269i  0.793+0.678i  0.792-0.770i -0.258+0.499i  0.127+0.760i;
#   1.355+0.521i  0.255+1.624i -0.195-0.320i  0.341-0.422i -0.496-1.176i  0.172+0.459i]
#
# [ 1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i]
#
# should be the same
# [ 3.144  2.926  2.151  1.258]
#
# ...

# %%
print('case RSIDE, m < n; FULL decomposition')
m=4;n=6
A=pv.create('cmview_d',m,n).fill(0.0)
A.realview.block.vector.randn(5)
A.imagview.block.vector.randn(7)
f='%.3f'
print('Test matrix')
A.mprint(f)
u,s,v=A.copy.svd
B=v.empty.fill(0.0)
B.diagview(0).fill(1)
B.mprint(f)
d=pv.SV('csv_d',m,n,'FULL','FULL')
S=s.empty.fill(0.0)
_=d.svd(A.copy,S)
print('should be the same')
S.mprint(f)
s.mprint(f)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_NTRANS,pv.VSIP_MAT_RSIDE,B.view)
print('should be the same; norm of difference should be small')
B.mprint(f)
v.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-v).normFro)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_RSIDE,B.view)
print('should be identity matrix')
B.mprint(f)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_RSIDE,B.view)
print('\nshould be the same; norm of difference should be small')
B.mprint(f)
v.herm.mprint(f)
print('Frobenius Norm %.4e'%(B-v.herm).normFro)
# Out:
# case RSIDE, m < n; FULL decomposition
# Test matrix
# [ 0.508-0.050i  0.535+0.590i  0.699+0.728i -0.960-0.368i  0.231-0.209i  0.040-0.827i;
#  -0.477-0.679i  0.208+0.012i  0.506-0.742i -0.383+0.375i  0.157-1.112i  0.781+2.007i;
#  -0.968+0.439i -0.320+1.269i  0.793+0.678i  0.792-0.770i -0.258+0.499i  0.127+0.760i;
#   1.355+0.521i  0.255+1.624i -0.195-0.320i  0.341-0.422i -0.496-1.176i  0.172+0.459i]
#
# [ 1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i]
#
# should be the same
# [ 3.144  2.926  2.151  1.258]
#
# ...

# %%
print('case LSIDE, m > n; FULL decomposition')
m=6;n=4
A=pv.create('cmview_d',m,n).fill(0.0)
A.realview.block.vector.randn(5)
A.imagview.block.vector.randn(7)
f='%.3f'
print('Test matrix')
A.mprint(f)
u,s,v=A.copy.svd
B=v.empty.fill(0.0)
B.diagview(0).fill(1)
B.mprint(f)
d=pv.SV('csv_d',m,n,'FULL','FULL')
S=s.empty.fill(0.0)
_=d.svd(A.copy,S)
print('should be the same')
S.mprint(f)
s.mprint(f)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_NTRANS,pv.VSIP_MAT_LSIDE,B.view)
print('should be the same; norm of difference should be small')
B.mprint(f)
v.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-v).normFro)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_LSIDE,B.view)
print('should be identity matrix')
B.mprint(f)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_LSIDE,B.view)
print('\nshould be the same; norm of difference should be small')
B.mprint(f)
v.herm.mprint(f)
print('Frobenius Norm %.4e'%(B-v.herm).normFro)
# Out:
# case LSIDE, m > n; FULL decomposition
# Test matrix
# [ 0.508-0.050i  0.535+0.590i  0.699+0.728i -0.960-0.368i;
#   0.231-0.209i  0.040-0.827i -0.477-0.679i  0.208+0.012i;
#   0.506-0.742i -0.383+0.375i  0.157-1.112i  0.781+2.007i;
#  -0.968+0.439i -0.320+1.269i  0.793+0.678i  0.792-0.770i;
#  -0.258+0.499i  0.127+0.760i  1.355+0.521i  0.255+1.624i;
#  -0.195-0.320i  0.341-0.422i -0.496-1.176i  0.172+0.459i]
#
# [ 1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i]
#
# should be the same
# [ 3.700  2.981  1.124  0.899]
#
# [ 3.700  2.981  1.124  0.899]
#
# should be the same; norm of difference should be small
# [ 0.270+0.000i -0.292+0.000i  0.832+0.000i -0.387+0.000i;
#   0.215+0.008i -0.273-0.508i -0.409-0.313i -0.524-0.285i;
#   0.540+0.335i  0.296-0.364i -0.029+0.044i  0.092+0.604i;
# ...

# %%
print('case RSIDE, m > n; FULL decomposition')
m=6;n=4
A=pv.create('cmview_d',m,n).fill(0.0)
A.realview.block.vector.randn(5)
A.imagview.block.vector.randn(7)
f='%.3f'
print('Test matrix')
A.mprint(f)
u,s,v=A.copy.svd
B=pv.create(v.type,v.collength,v.collength).fill(0.0)
B.diagview(0).fill(1)
B.mprint(f)
d=pv.SV('csv_d',m,n,'FULL','FULL')
S=s.empty.fill(0.0)
_=d.svd(A.copy,S)
print('should be the same')
S.mprint(f)
s.mprint(f)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_NTRANS,pv.VSIP_MAT_RSIDE,B.view)
print('should be the same; norm of difference should be small')
B.mprint(f)
v.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-v).normFro)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_RSIDE,B.view)
print('should be identity matrix')
B.mprint(f)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_RSIDE,B.view)
print('\nshould be the same; norm of difference should be small')
B.mprint(f)
v.herm.mprint(f)
print('Frobenius Norm %.4e'%(B-v.herm).normFro)
# Out:
# case RSIDE, m > n; FULL decomposition
# Test matrix
# [ 0.508-0.050i  0.535+0.590i  0.699+0.728i -0.960-0.368i;
#   0.231-0.209i  0.040-0.827i -0.477-0.679i  0.208+0.012i;
#   0.506-0.742i -0.383+0.375i  0.157-1.112i  0.781+2.007i;
#  -0.968+0.439i -0.320+1.269i  0.793+0.678i  0.792-0.770i;
#  -0.258+0.499i  0.127+0.760i  1.355+0.521i  0.255+1.624i;
#  -0.195-0.320i  0.341-0.422i -0.496-1.176i  0.172+0.459i]
#
# [ 1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i]
#
# should be the same
# [ 3.700  2.981  1.124  0.899]
#
# [ 3.700  2.981  1.124  0.899]
#
# should be the same; norm of difference should be small
# [ 0.270+0.000i -0.292+0.000i  0.832+0.000i -0.387+0.000i;
#   0.215+0.008i -0.273-0.508i -0.409-0.313i -0.524-0.285i;
#   0.540+0.335i  0.296-0.364i -0.029+0.044i  0.092+0.604i;
# ...

# %%
print('case LSIDE, m < n; PART decomposition')
m=4;n=6
A=pv.create('cmview_d',m,n).fill(0.0)
A.realview.block.vector.randn(5)
A.imagview.block.vector.randn(7)
f='%.3f'
print('Test matrix')
A.mprint(f)
u,s,v=A.copy.svdP
B0=v.empty.fill(0.0)
B=B0[:v.rowlength,:]
B.diagview(0).fill(1.0)
B.mprint(f)
d=pv.SV('csv_d',m,n,'PART','PART')
S=s.empty.fill(0.0)
_=d.svd(A.copy,S)
print('should be the same')
S.mprint(f)
s.mprint(f)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_NTRANS,pv.VSIP_MAT_LSIDE,B.view)
print('should be the same; norm of difference should be small')
B0.mprint(f)
v.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-v).normFro)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_LSIDE,B0.view)
print('should be identity matrix')
B.mprint(f)
B1=pv.create(v.type,v.collength,v.collength).fill(0.0)
B1.diagview(0).fill(1.0)
B=B1[:v.rowlength,:]
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_LSIDE,B1.view)
print('\nshould be the same; norm of difference should be small')
B.mprint(f)
v.herm.mprint(f)
print('Frobenius Norm %.4e'%(B-v.herm).normFro)
# Out:
# case LSIDE, m < n; PART decomposition
# Test matrix
# [ 0.508-0.050i  0.535+0.590i  0.699+0.728i -0.960-0.368i  0.231-0.209i  0.040-0.827i;
#  -0.477-0.679i  0.208+0.012i  0.506-0.742i -0.383+0.375i  0.157-1.112i  0.781+2.007i;
#  -0.968+0.439i -0.320+1.269i  0.793+0.678i  0.792-0.770i -0.258+0.499i  0.127+0.760i;
#   1.355+0.521i  0.255+1.624i -0.195-0.320i  0.341-0.422i -0.496-1.176i  0.172+0.459i]
#
# [ 1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i]
#
# should be the same
# [ 3.144  2.926  2.151  1.258]
#
# [ 3.144  2.926  2.151  1.258]
#
# should be the same; norm of difference should be small
# [-0.371-0.003i  0.371-0.098i -0.543-0.139i  0.168-0.203i;
#  -0.614+0.231i  0.126-0.180i  0.206+0.143i  0.236+0.170i;
#  -0.032-0.194i  0.211-0.315i  0.463-0.003i -0.254+0.465i;
# ...

# %%
print('case RSIDE, m < n; PART decomposition')
m=4;n=6
A=pv.create('cmview_d',m,n).fill(0.0)
A.realview.block.vector.randn(5)
A.imagview.block.vector.randn(7)
f='%.3f'
print('Test matrix')
A.mprint(f)
u,s,v=A.copy.svdP
B0=pv.create(v.type,v.collength,v.collength).fill(0.0)
B0.diagview(0).fill(1)
B=B0[:,:v.rowlength]
B0.mprint(f)
d=pv.SV('csv_d',m,n,'PART','PART')
S=s.empty.fill(0.0)
_=d.svd(A.copy,S)
print('should be the same')
S.mprint(f)
s.mprint(f)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_NTRANS,pv.VSIP_MAT_RSIDE,B0.view)
print('should be the same; norm of difference should be small')
B.mprint(f)
v.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-v).normFro)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_RSIDE,B.view)
print('should be the same')
B0.mprint(f)
(v.prod(v.herm)).mprint(f)
B1=B0[:v.rowlength,:].fill(0.0);B1.diagview(0).fill(1.0)
B=B1[:,:v.rowlength]
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_RSIDE,B.view)
print('\nshould be the same; norm of difference should be small')
B1.mprint(f)
v.herm.mprint(f)
print('Frobenius Norm %.4e'%(B1-v.herm).normFro)
# Out:
# case RSIDE, m < n; PART decomposition
# Test matrix
# [ 0.508-0.050i  0.535+0.590i  0.699+0.728i -0.960-0.368i  0.231-0.209i  0.040-0.827i;
#  -0.477-0.679i  0.208+0.012i  0.506-0.742i -0.383+0.375i  0.157-1.112i  0.781+2.007i;
#  -0.968+0.439i -0.320+1.269i  0.793+0.678i  0.792-0.770i -0.258+0.499i  0.127+0.760i;
#   1.355+0.521i  0.255+1.624i -0.195-0.320i  0.341-0.422i -0.496-1.176i  0.172+0.459i]
#
# [ 1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i]
#
# should be the same
# [ 3.144  2.926  2.151  1.258]
#
# ...

# %%
print('case LSIDE, m > n; PART decomposition')
m=6;n=4
A=pv.create('cmview_d',m,n).fill(0.0)
A.realview.block.vector.randn(5)
A.imagview.block.vector.randn(7)
f='%.3f'
print('Test matrix')
A.mprint(f)
u,s,v=A.copy.svdP
B=pv.create(v.type,n,n).fill(0.0)
B.diagview(0).fill(1)
B.mprint(f)
d=pv.SV('csv_d',m,n,'PART','PART')
S=s.empty.fill(0.0)
_=d.svd(A.copy,S)
print('should be the same')
S.mprint(f)
s.mprint(f)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_NTRANS,pv.VSIP_MAT_LSIDE,B.view)
print('should be the same; norm of difference should be small')
B.mprint(f)
v.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-v).normFro)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_LSIDE,B.view)
print('should be identity matrix')
B.mprint(f)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_LSIDE,B.view)
print('\nshould be the same; norm of difference should be small')
B.mprint(f)
v.herm.mprint(f)
print('Frobenius Norm %.4e'%(B-v.herm).normFro)
# Out:
# case LSIDE, m > n; PART decomposition
# Test matrix
# [ 0.508-0.050i  0.535+0.590i  0.699+0.728i -0.960-0.368i;
#   0.231-0.209i  0.040-0.827i -0.477-0.679i  0.208+0.012i;
#   0.506-0.742i -0.383+0.375i  0.157-1.112i  0.781+2.007i;
#  -0.968+0.439i -0.320+1.269i  0.793+0.678i  0.792-0.770i;
#  -0.258+0.499i  0.127+0.760i  1.355+0.521i  0.255+1.624i;
#  -0.195-0.320i  0.341-0.422i -0.496-1.176i  0.172+0.459i]
#
# [ 1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i]
#
# should be the same
# [ 3.700  2.981  1.124  0.899]
#
# [ 3.700  2.981  1.124  0.899]
#
# should be the same; norm of difference should be small
# [ 0.270+0.000i -0.292+0.000i  0.832+0.000i -0.387+0.000i;
#   0.215+0.008i -0.273-0.508i -0.409-0.313i -0.524-0.285i;
#   0.540+0.335i  0.296-0.364i -0.029+0.044i  0.092+0.604i;
# ...

# %%
print('case RSIDE, m > n; PART decomposition')
m=6;n=4
A=pv.create('cmview_d',m,n).fill(0.0)
A.realview.block.vector.randn(5)
A.imagview.block.vector.randn(7)
f='%.3f'
print('Test matrix')
A.mprint(f)
u,s,v=A.copy.svdP
B=pv.create(v.type,n,n).fill(0.0)
B.diagview(0).fill(1)
B.mprint(f)
d=pv.SV('csv_d',m,n,'PART','PART')
S=s.empty.fill(0.0)
_=d.svd(A.copy,S)
print('should be the same')
S.mprint(f)
s.mprint(f)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_NTRANS,pv.VSIP_MAT_RSIDE,B.view)
print('should be the same; norm of difference should be small')
B.mprint(f)
v.mprint(f)
print('Frobenius Norm %.4e\n\n'%(B-v).normFro)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_RSIDE,B.view)
print('should be identity matrix')
B.mprint(f)
pv.vsip_csvdprodv_d(d.vsip,pv.VSIP_MAT_HERM,pv.VSIP_MAT_RSIDE,B.view)
print('\nshould be the same; norm of difference should be small')
B.mprint(f)
v.herm.mprint(f)
print('Frobenius Norm %.4e'%(B-v.herm).normFro)
# Out:
# case RSIDE, m > n; PART decomposition
# Test matrix
# [ 0.508-0.050i  0.535+0.590i  0.699+0.728i -0.960-0.368i;
#   0.231-0.209i  0.040-0.827i -0.477-0.679i  0.208+0.012i;
#   0.506-0.742i -0.383+0.375i  0.157-1.112i  0.781+2.007i;
#  -0.968+0.439i -0.320+1.269i  0.793+0.678i  0.792-0.770i;
#  -0.258+0.499i  0.127+0.760i  1.355+0.521i  0.255+1.624i;
#  -0.195-0.320i  0.341-0.422i -0.496-1.176i  0.172+0.459i]
#
# [ 1.000+0.000i  0.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  1.000+0.000i  0.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  1.000+0.000i  0.000+0.000i;
#   0.000+0.000i  0.000+0.000i  0.000+0.000i  1.000+0.000i]
#
# should be the same
# [ 3.700  2.981  1.124  0.899]
#
# [ 3.700  2.981  1.124  0.899]
#
# should be the same; norm of difference should be small
# [ 0.270+0.000i -0.292+0.000i  0.832+0.000i -0.387+0.000i;
#   0.215+0.008i -0.273-0.508i -0.409-0.313i -0.524-0.285i;
#   0.540+0.335i  0.296-0.364i -0.029+0.044i  0.092+0.604i;
# ...
