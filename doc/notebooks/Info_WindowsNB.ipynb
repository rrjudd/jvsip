# %%
import pyJvsip as pjv
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.hold=True
plt.plot(pjv.create('kaiser_f',10,9),'r')
plt.plot(pjv.Block('kaiser_d',10,9).w,'v')
plt.hold=False

# %%
plt.hold=True
plt.plot(pjv.create('cheby_f',30,50),'r')
plt.plot(pjv.Block('cheby_d',30,50).w,'v')
plt.hold=False

# %%
plt.hold=True
plt.plot(pjv.create('blackman_f',30),'r')
plt.plot(pjv.Block('blackman_d',30).w,'v')
plt.hold=False

# %%
plt.hold=True
plt.plot(pjv.create('hanning_f',30),'r')
plt.plot(pjv.Block('hanning_d',30).w,'v')
plt.hold=False

# %%
a = pjv.create('hanning_f',150)

# %%
y=a.fftop
pjv.freqswap(y)
z=y.copy.cmagsq
plt.plot(z[50:100])

# %%
x=z[10:20]
z.mprint('%.2f')
x.mprint('%.2f')
# Out:
# [ 3.76  3.15 -1.57 -2.42 -2.97 -3.38 -3.70 -3.98 -4.22 -4.43 -4.61 -4.78 -4.93 -5.08 -5.21 -5.33 -5.44 -5.55 -5.65 -5.75 -5.84 -5.93 -6.02 -6.10 -6.17 -6.25 -6.32 -6.39 -6.46 -6.53 -6.59 -6.65 -6.71 -6.77 -6.83 -6.89 -6.94 -7.00 -7.06 -7.11 -7.16 -7.21 -7.27 -7.32 -7.37 -7.42 -7.47 -7.52 -7.58 -7.63 -7.68 -7.74 -7.79 -7.84 -7.89 -7.95 -8.00 -8.08 -8.13 -8.22 -8.25 -8.34 -8.41 -8.48 -8.57 -8.66 -8.78 -8.84 -8.92 -9.12 -9.27 -9.49 -9.70 -10.03 -10.18 -inf -10.67 -10.03 -9.70 -9.46 -9.30 -9.12 -8.91 -8.84 -8.78 -8.66 -8.58 -8.48 -8.42 -8.33 -8.25 -8.20 -8.14 -8.08 -8.01 -7.95 -7.89 -7.84 -7.79 -7.74 -7.67 -7.63 -7.58 -7.52 -7.47 -7.42 -7.37 -7.32 -7.27 -7.21 -7.16 -7.11 -7.06 -7.00 -6.94 -6.89 -6.83 -6.77 -6.71 -6.65 -6.59 -6.52 -6.46 -6.39 -6.32 -6.25 -6.17 -6.10 -6.01 -5.93 -5.84 -5.75 -5.65 -5.55 -5.44 -5.33 -5.21 -5.08 -4.93 -4.78 -4.61 -4.43 -4.22 -3.98 -3.70 -3.38 -2.97 -2.42 -1.57  3.15]
#
# [-4.61 -4.78 -4.93 -5.08 -5.21 -5.33 -5.44 -5.55 -5.65 -5.75]
