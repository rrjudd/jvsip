# %%
import pyJvsip as pv
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.hold=True
plt.plot(pv.create('kaiser_f',10,9),'r')
plt.plot(pv.Block('kaiser_d',10,9).w,'v')
plt.hold=False
# Out:
# Input type <:kaiser_f:> not recognzied for create

# %%
plt.hold=True
plt.plot(pv.create('cheby_f',30,50),'r')
plt.plot(pv.Block('cheby_d',30,50).w,'v')
plt.hold=False
# Out:
# Input type <:cheby_f:> not recognzied for create

# %%
plt.hold=True
plt.plot(pv.create('blackman_f',30),'r')
plt.plot(pv.Block('blackman_d',30).w,'v')
plt.hold=False
# Out:
# Input type <:blackman_f:> not recognzied for create

# %%
plt.hold=True
plt.plot(pv.create('hanning_f',30),'r')
plt.plot(pv.Block('hanning_d',30).w,'v')
plt.hold=False
# Out:
# Input type <:hanning_f:> not recognzied for create
